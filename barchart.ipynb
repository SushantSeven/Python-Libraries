# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Write a Python programming to display a bar chart of the popularity of programming
# Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.bar(languages, popularity, width=0.4)
plt.xlabel('Programming languages')
plt.ylabel('Popularity')
plt.title('Programming languages popularity')
plt.show()

# %% [markdown]
# 2. Write a Python programming to display a horizontal bar chart of the popularity of
# programming Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
plt.barh(languages,popularity,height=0.4)
plt.xlabel('Popularity')
plt.ylabel('Languages')
plt.title('Programming languages popularity')
plt.show()

# %% [markdown]
# 3. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Use uniform color.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
plt.bar(languages, popularity, width=0.4)
plt.xlabel('Programming languages')
plt.ylabel('Popularity')
plt.title('Programming languages popularity')
plt.show()

# %% [markdown]
# 4. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Use different color for each bar.
#
# use color list

# %%
c = ["blue", "green", "yellow", "orange", "red","black"]
plt.bar(languages,popularity, color = c)
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.title('Programming languages popularity')
plt.show()

# %% [markdown]
# 5. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Attach a text label above each bar displaying its popularity (float value).
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
barch = plt.bar(languages, popularity, width=0.4)
plt.xlabel('Programming languages')
plt.ylabel('Popularity')
plt.bar_label(barch,labels=popularity)
plt.title('Programming languages popularity')
plt.show()

# %% [markdown]
# 6. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Make blue border to each bar.

# %%
barch = plt.bar(languages, popularity, width=0.4,color='yellow', edgecolor = 'blue')
plt.xlabel('Programming languages')
plt.ylabel('Popularity')
plt.bar_label(barch,labels=popularity)
plt.title('Programming languages popularity')
plt.show()

# %% [markdown]
# 7. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Specify the position of each bar plot.

# %%
c = ["blue", "green", "yellow", "orange", "red","black"]
x_pos = [0,4,6,8,9,10]
 
plt.bar(x_pos,popularity, color = c)
plt.xticks(x_pos,languages)
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.title('Programming languages popularity')
plt.show()

# %% [markdown]
# 8. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Select the width of each bar and their positions.

# %%
width = [2.1, 1.5, 1.2, 0.5, 0.2, 0.2]
barch = plt.bar(x_pos, popularity, width=width)
plt.xlabel('Programming languages')
plt.ylabel('Popularity')
plt.title('Programming languages popularity')
plt.bar_label(barch,labels=popularity)
plt.xticks(x_pos, languages)
plt.show()

# %% [markdown]
# 9. Write a Python programming to display a bar chart of the popularity of programming
# Languages. Increase bottom margin.
#
# plt.subplots_adjust(bottom=0.4, top=0.8)

# %%
c = ["pink", "green", "yellow", "orange", "red","black"]
plt.bar(languages,popularity,width = 0.2, color = c)
plt.subplots_adjust(bottom=0.4)
plt.xlabel("Programming Languages")
plt.title('Programming languages popularity')
plt.ylabel("Popularity")
plt.subplots_adjust(bottom=0.4, top=0.8)
plt.show()

# %% [markdown]
#     10. Write a Python program to create bar plot of scores by group and gender. Use multiple X
#     values on the same chart for men and women.
#     Sample Data:
#     Means (men) = (22, 30, 35, 35, 26)
#     Means (women) = (25, 32, 30, 35, 29)

# %%
men = [22, 30, 35, 35, 26]
women = [25, 32, 30, 35, 29]
group = ['g1','g2','g3','g4','g5']
xposition = np.arange(len(group))
plt.bar(xposition-0.4, men, label='men', width=0.4)
plt.bar(xposition, women,label='women', width=0.4, color='red')
plt.xticks(xposition,group)
plt.title('Scores')
plt.legend()
plt.show()

# %% [markdown]
# 11. Write a Python program to create bar plot from a DataFrame.
# Sample Data Frame:
# a b c d e
# 2 4,8,5,7,6
# 4 2,3,4,2,6
# 6 4,7,4,7,8
# 8 2,6,4,8,6
# 10 2,4,3,3,2

# %%
indices = [2,4,6,8,10]
sample_df = pd.DataFrame({'a':[4,2,4,2,2],'b':[8,3,7,6,4],'c':[5,4,4,4,3],'d':[7,2,7,8,3],'e':[6,6,8,6,2]}, index=indices)
print('The dataframe')
sample_df
# Out:
# The dataframe
#     a  b  c  d  e
# 2   4  8  5  7  6
# 4   2  3  4  2  6
# 6   4  7  4  7  8
# 8   2  6  4  8  6
# 10  2  4  3  3  2

# %%
sample_df.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# 12. Write a Python program to create bar plots with error bars on the same figure. Sample Date
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645

# %%
mean_velocity = [0.2474, 0.1235, 0.1737, 0.1824]
standard_dev = [0.3314, 0.2278, 0.2836, 0.2645]
ind = np.arange(len(mean_velocity))
mean_bar = plt.bar(ind,mean_velocity, width=0.4, yerr = standard_dev)
plt.ylim(0,0.75)
plt.show()

# %% [markdown]
# 13. Write a Python program to create bar plots with errorbars on the same figure. Attach a text
# label above each bar displaying men means (integer value).

# %%
mean_velocity = [0.2474, 0.1235, 0.1737, 0.1824]
standard_dev = [0.3314, 0.2278, 0.2836, 0.2645]
ind = np.arange(len(mean_velocity))
mean_bar = plt.bar(ind,mean_velocity, width=0.4, yerr = standard_dev)
plt.bar_label(mean_bar,mean_velocity)
plt.ylim(0,0.75)
plt.show()
