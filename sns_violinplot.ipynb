# %% [markdown]
# 1. Write a program to draw a violin plot of sex against total_bill for a given dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

total_bill_df = pd.read_csv('total_bil.csv')
sns.violinplot(data=total_bill_df, x='sex',y = 'total_bill')
plt.show()

# %% [markdown]
# 2. Write a program to draw a violin plot of “species” against “sepal length” for a dataset
# given in a url

# %%
iris_df = pd.read_csv('iris.csv')
sns.violinplot(data=iris_df,x='species',y='sepal_width')
plt.show()
